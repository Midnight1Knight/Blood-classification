# %% [markdown]
# 1. Импорт данных

# %% [markdown]
# Установка зависимостей и установка

# %%
'''
Ошибка № 1. Возникала ошибка InvalidArgumentError: Input Data is Empty при обучении модели и при выполнении команды:
image_count = len(list(data_carp))
print(image_count)
Решение: 2 изображения в папке "миелоцит" были повреждены (не открывалсь в Гугл диске). Данные изображения были удалены.


'''
# Out:
# '\nОшибка № 1. Возникала ошибка InvalidArgumentError: Input Data is Empty при обучении модели и при выполнении команды:\nimage_count = len(list(data_carp))\nprint(image_count)\nРешение: 2 изображения в папке "миелоцит" были повреждены (не открывалсь в Гугл диске). Данные изображения были удалены.\n\n\n'

# %%
# работа с файловой системой
import os
import tensorflow as tf
# Out:
# 2023-06-30 15:05:37.266704: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-30 15:05:37.861096: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# 2023-06-30 15:05:38.541020: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-30 15:05:38.576386: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# Установка данных

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# подключение к вашему гугл диску, на котором имеется папка с данными
# from google.colab import drive 
# drive.mount('/content/gdrive')

# %%
# Download and explore the dataset
import PIL
import pathlib
dataset_url = './data/Изображения подготовленные/Осетр'
data_dir = pathlib.Path(dataset_url)

image_count = len(list(data_dir.glob('*/*.*')))
print('image_count:', image_count)

paths = list(data_dir.glob('*/*.*'))

classes_names = list(str(data_dir.glob('*')))
# Out:
# image_count: 640

# %%
# Имена классов
classes_paths = list((data_dir.glob('*/*.*')))
classes_paths = list(map(str, classes_paths)) # Список элементов str

classes_names = list((data_dir.glob('*'))) # Спиок элементов PosixPath
classes_n = len(classes_names)
classes_names = list(map(str, classes_names)) # Список элементов str
classes_names = [classes_names[i][classes_names[i].rfind(r'/') + 1:] for i in range(classes_n)]

print(classes_paths)
print(classes_names)
print(classes_n)
# Out:
# ['data/Изображения подготовленные/Осетр/эозинофил/Эозинофил3.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эз22.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил 6.PNG', 'data/Изображения подготовленные/Осетр/эозинофил/эозинофил 6-рус 1.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил1.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эз24.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эозинофил 3-стерлядь 1.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эз25.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эозинофил 2.PNG', 'data/Изображения подготовленные/Осетр/эозинофил/5.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эз26.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эозинофил 1.PNG', 'data/Изображения подготовленные/Осетр/эозинофил/1.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил5.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эозинофил 6-рус 5.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эз27.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эозинофил 6-рус 3.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эозинофил 1-рус 1.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эозинофил 6-рус 2.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/эз23.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил4.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил2.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил 8.PNG', 'data/Изображения подготовленные/Осетр/эозинофил/эозинофил 6-рус 4.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/л1.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эизинофил7.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил 2(1).PNG', 'data/Изображения подготовленные/Осетр/эозинофил/эозинофил 2-ленский 1.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил 1(1).PNG', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил 5.PNG', 'data/Изображения подготовленные/Осетр/эозинофил/4.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил 4.PNG', 'data/Изображения подготовленные/Осетр/эозинофил/эозинофил 2-ленский 2.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/3.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/2.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил 3.PNG', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил 9.PNG', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил6.jpg', 'data/Изображения подготовленные/Осетр/эозинофил/Эозинофил 7.PNG', 'data/Изображения подготовленные/Осетр/эозинофил/эз9.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 5-ленск 16.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 1-рус 2.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 1-рус 3.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 1-рус 1.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 5-ленск 3.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 5-ленск 10.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 5-ленск 13.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 6-рус 4.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 5-ленск 8.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит (1).PNG', 'data/Изображения подготовленные/Осетр/моноцит/5.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 3-стерлядь 1.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 5-ленск 15.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 5-ленск 11.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 5-ленск 7.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 5-1.jpg', 'data/Изображения подготовленные/Осетр/моноцит/1.jpg', 'data/Изображения подготовленные/Осетр/моноцит/Моноцит 5-ленский 1.jpg', 'data/Изображения подготовленные/Осетр/моноцит/моноцит 5-ленс ...
# ['эозинофил', 'моноцит', 'миелоцит', 'палочкоядерный нейтрофил', 'тромбоцит', 'метамиелоцит', 'нормобласт', 'миелобласт', 'лимфоцит', 'сегментоядерный нейтрофил', 'базофил', 'промиелоцит', 'эритробласт', 'зрелый эритроцит']
# 14

# %%
#list((data_dir.glob('*' + str(classes_names[6]) + '/*.*')))

# %%
#list((data_dir.glob(r'*content/gdrive/MyDrive/Клетки крови рыб/Изображения подготовленные/Карп/миелоцит/*.*')))

# %%
import seaborn as sns
classes_sizes = []

for i in range(classes_n):
    counter = 0
    class_folderName = '/' + classes_names[i] + '/'
    for j in range(image_count):
        if class_folderName in classes_paths[j]:
            counter += 1
    classes_sizes.append(counter)

print('classes_sizes:', classes_sizes)
print('sum(classes_sizes):', sum(classes_sizes))


sns.barplot(y = classes_names, x = classes_sizes, color = 'lightblue')
# Out:
# classes_sizes: [41, 42, 25, 29, 110, 3, 30, 11, 88, 48, 6, 9, 6, 192]
# sum(classes_sizes): 640
# <Axes: >

# %%
#list((data_dir.glob('*/' + str(classes_names[0]) )))
classes_sizes = [len(list((data_dir.glob('*' + str(classes_names[i]) + '/*.*')))) for i in range(classes_n)]
print('classes_sizes:', classes_sizes)
print('sum(classes_sizes):', sum(classes_sizes))
# Out:
# classes_sizes: [41, 42, 37, 29, 110, 3, 30, 11, 88, 48, 6, 9, 6, 192]
# sum(classes_sizes): 652

# %%
data_osetr = tf.keras.utils.image_dataset_from_directory('./data/Изображения подготовленные/Осетр')
print(tf.data.experimental.cardinality(data_osetr).numpy())

image_count = len(list(data_osetr))
print(image_count)
# Out:
# Found 640 files belonging to 14 classes.
# 20
# 20
# 2023-06-30 15:05:39.257011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [640]
# 	 [[{{node Placeholder/_4}}]]
# 2023-06-30 15:05:39.257240: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [640]
# 	 [[{{node Placeholder/_4}}]]

# %%
list(data_osetr)
# Out:
# [(<tf.Tensor: shape=(32, 256, 256, 3), dtype=float32, numpy=
#   array([[[[241.      , 223.      , 223.      ],
#            [240.38672 , 222.38672 , 222.38672 ],
#            [240.      , 222.      , 222.      ],
#            ...,
#            [239.      , 219.      , 221.      ],
#            [239.38672 , 219.38672 , 221.38672 ],
#            [240.      , 220.      , 222.      ]],
#
#           [[241.      , 223.      , 223.      ],
#            [240.88861 , 222.88861 , 222.88861 ],
#            [240.52747 , 222.52747 , 222.52747 ],
#            ...,
#            [239.      , 219.      , 221.      ],
#            [239.07025 , 219.07025 , 221.07025 ],
#            [239.18164 , 219.18164 , 221.18164 ]],
#
#           [[241.      , 223.      , 223.      ],
#            [241.      , 223.      , 223.      ],
#            [240.8924  , 222.8924  , 222.8924  ],
#            ...,
#            [239.      , 219.      , 221.      ],
#            [239.      , 219.      , 221.      ],
#            [239.      , 219.      , 221.      ]],
#
#           ...,
#
#           [[209.      , 179.      , 187.      ],
#            [209.61328 , 179.61328 , 187.61328 ],
#            [209.64453 , 180.71094 , 188.35547 ],
#            ...,
#            [229.64453 , 214.64453 , 217.64453 ],
#            [230.      , 215.      , 218.      ],
#            [230.      , 215.      , 218.      ]],
#
#           [[208.63672 , 178.81836 , 186.27344 ],
#            [209.36139 , 179.54303 , 186.99811 ],
#            [209.52747 , 180.71094 , 188.00424 ],
#            ...,
#            [229.64453 , 214.7091  , 217.5154  ],
#            [230.      , 215.      , 218.      ],
#            [230.      , 215.      , 218.      ]],
#
#           [[207.      , 178.      , 183.      ],
#            [208.22656 , 179.22656 , 184.22656 ],
#            [209.      , 180.71094 , 186.42188 ],
#            ...,
#            [229.64453 , 215.      , 216.9336  ],
#            [230.      , 215.      , 218.      ],
#            [230.      , 215.      , 218.      ]]],
#
#
#          [[[211.      , 234.      , 180.      ],
#            [211.      , 234.      , 180.      ],
#            [211.      , 234.      , 180.      ],
#            ...,
#            [214.63281 , 232.63281 , 184.63281 ],
#            [214.17969 , 232.17969 , 184.17969 ],
#            [214.      , 232.      , 184.      ]],
#
#           [[211.      , 234.      , 180.      ],
#            [211.      , 234.      , 180.      ],
#            [211.      , 234.      , 180.      ],
#            ...,
#            [214.53134 , 232.53134 , 184.53134 ],
#            [214.04459 , 232.04459 , 184.04459 ],
#            [213.85156 , 231.85156 , 183.85156 ]],
#
#           [[211.      , 234.      , 180.      ],
#            [211.      , 234.      , 180.      ],
#            [211.      , 234.      , 180.      ],
#            ...,
#            [196.       , 218.       , 169.       ],
#            [196.       , 218.       , 169.       ],
#            [196.       , 218.       , 169.       ]],
#
#           [[185.10938  , 209.89062  , 155.       ],
#            [185.10852  , 209.89062  , 154.99957  ],
#            [185.03503  , 209.89062  , 154.96283  ],
#            ...,
#            [195.78125  , 217.78125  , 168.78125  ],
#            [195.78125  , 217.78125  , 168.78125  ],
#            [195.78125  , 217.78125  , 168.78125  ]],
#
#           [[185.51562  , 209.48438  , 155.       ],
#            [185.5116   , 209.48438  , 154.99799  ],
#            [185.16516  , 209.48438  , 154.82477  ],
#            ...,
#            [194.96875  , 216.96875  , 167.96875  ],
#            [194.96875  , 216.96875  , 167.96875  ],
#            [194.96875  , 216.96875  , 167.96875  ]],
#
#           ...,
#
#           [[ 21.890625 ,  29.921875 ,  65.21875  ],
#            [ 21.869202 ,  29.91217  ,  65.19165  ],
#            [ 20.026794 ,  29.077576 ,  62.861084 ],
#            ...,
#            [177.97992  , 206.97992  , 152.97992  ],
#            [178.47858  , 207.47858  , 153.47858  ],
#            [178.48438  , 207.48438  , 153.48438  ]],
#
#           [[ 11.734375 ,  18.953125 ,  59.53125  ],
#            [ 11.711365 ,  18.941833 ,  59.497803 ],
#            [  9.732483 ,  17.970764 ,  56.621338 ],
#            ...,
#            [178.24811  , 207.24811  , 153.24811  ],
#            [178.88324  , 207.88324  , 153.88324  ],
#            [178.89062  , 207.89062  , 153.89062  ]],
#
#           [[  9.       ,  16.       ,  58.       ],
#            [  8.9765625,  15.988281 ,  57.964844 ],
#            [  6.9609375,  14.980469 ,  54.941406 ],
#            ...,
#            [178.32031  , 207.32031  , 153.32031  ],
#            [178.99219  , 207.99219  , 153.99219  ],
#            [179.       , 208.       , 154.       ]]],
#
#
#          [[[184.82031  , 208.82031  , 110.82031  ],
#            [180.26953  , 204.26953  , 106.26953  ],
#            [181.12508  , 205.12508  , 107.12508  ],
#            ...,
#            [191.53906  , 216.53906  , 115.53906  ],
#            [191.53906  , 216.53906  , 114.53906  ],
#            [192.59767  , 216.14845  , 112.699234 ]],
#
#           [[182.748    , 208.748    , 109.748    ],
#            [179.51549  , 205.51549  , 106.51549  ],
#            [180.99414  , 206.99414  , 107.99414  ],
#            ...,
#            [190.61719  , 215.61719  , 114.61719  ],
#            [192.61719  , 214.61719  , 113.61719  ],
#            [192.61719  , 214.61719  , 113.61719  ]],
#
#           [[179.0586   , 207.0586   , 107.05859  ],
#            [177.60938  , 205.60938  , 105.609375 ],
#            [179.2621   , 207.2621   , 107.2621   ],
#            ...,
#            [191.       , 213.       , 113.       ],
#            [191.69531  , 213.69531  , 113.69531  ],
#            [192.41992  , 213.69531  , 112.9707   ]],
#
#           ...,
#
#           [[179.58774  , 201.16219  , 105.9707   ],
#            [179.37569  , 203.2168   , 107.26976  ],
#            [178.75157  , 203.50548  , 107.128525 ],
#            ...,
#            [188.68164  , 213.68164  , 111.68164  ],
#            [188.47852  , 213.47852  , 111.478516 ],
#            [119.05377  ,  55.762177 , 160.85938  ],
#            [119.13281  ,  56.132812 , 161.13281  ]],
#
#           [[227.       , 213.       , 213.       ],
#            [226.9797   , 212.9797   , 212.9797   ],
#            [226.94144  , 212.94144  , 212.94144  ],
#            ...,
#            [123.22662  ,  58.035126 , 163.76562  ],
#            [122.78754  ,  59.028107 , 164.28125  ],
#            [122.55469  ,  59.554688 , 164.55469  ]],
#
#           ...,
#
#           [[216.       , 201.       , 204.       ],
#            [216.27344  , 201.27344  , 204.27344  ],
#            [216.78906  , 201.78906  , 204.78906  ],
#            ...,
#            [200.7305   , 167.7305   , 186.7305   ],
#            [200.25314  , 167.25314  , 186.25314  ],
#            [200.       , 167.       , 186.       ]],
#
#           [[216.       , 201.       , 204.       ],
#            [216.27344  , 201.27344  , 204.27344  ],
#            [216.78906  , 201.78906  , 204.78906  ],
#            ...,
#            [200.28049  , 167.28049  , 186.28049  ],
#            [200.0972   , 167.0972   , 186.0972   ],
#            [200.       , 167.       , 186.       ]],
#
#           [[216.       , 201.       , 204.       ],
#            [216.27344  , 201.27344  , 204.27344  ],
#            [216.78906  , 201.78906  , 204.78906  ],
#            ...,
#            [200.       , 167.       , 186.       ],
#            [200.       , 167.       , 186.       ],
#            [200.       , 167.       , 186.       ]]],
#
#
#          [[[255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            ...,
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ]],
#
#           [[255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            ...,
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ]],
#
#           [[255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            ...,
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ]],
#
#           ...,
#
#           [[255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            ...,
#            [227.68349  , 196.49994  , 179.05057  ],
#            [227.3164   , 195.8125   , 178.06445  ],
#            [227.3164   , 194.3164   , 177.3164   ]],
#
#           [[255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            ...,
#            [227.       , 196.       , 178.       ],
#            [227.       , 195.4961   , 177.54137  ],
#            [227.       , 194.       , 176.17969  ]],
#
#           [[255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            [255.       , 255.       , 255.       ],
#            ...,
#            [227.       , 196.       , 178.       ],
#            [227.       , 195.4961   , 177.24414  ],
#            [227.       , 194.       , 175.       ]]],
#
#
#          [[[166.       , 123.       , 202.       ],
#            [173.1289   , 130.1289   , 209.1289   ],
#            [169.2207   , 127.26367  , 205.74219  ],
#            ...,
#            [209.8711   , 194.8711   , 215.8711   ],
#            [209.55469  , 193.69336  , 214.98047  ],
#            [201.       , 183.       , 205.       ]],
#
#           [[170.76562  , 127.765625 , 206.76562  ],
#            [177.46986  , 135.3192   , 213.89453  ],
#            [174.01193  , 132.625    , 210.81847  ],
#            ...,
#            [211.0369   , 196.6582   , 217.34755  ],
#            [211.85489  , 195.99356  , 217.28067  ],
#            [204.57422  , 186.57422  , 208.57422  ]],
#
#           [[170.08594  , 127.73828  , 205.75977  ],
#            [176.96701  , 135.58008  , 213.1212   ],
#            [174.17204  , 133.17204  , 210.5197   ],
#            ...,
#            [212.46646  , 198.50943  , 218.98795  ],
#            [214.48817  , 198.62685  , 219.91396  ],
#            [208.30469  , 190.30469  , 212.30469  ]],
#
#           ...,
#
#            [234.       , 249.       , 244.       ],
#            [233.       , 250.       , 244.       ]],
#
#           ...,
#
#           [[194.34766  , 186.34766  , 150.34766  ],
#            [198.72852  , 190.72852  , 153.72852  ],
#            [200.52856  , 192.30005  , 153.30005  ],
#            ...,
#            [230.77148  , 246.77148  , 245.77148  ],
#            [230.77148  , 246.77148  , 245.77148  ],
#            [230.77148  , 246.77148  , 245.77148  ]],
#
#           [[192.05148  , 184.05148  , 148.05148  ],
#            [195.22864  , 187.22864  , 150.22864  ],
#            [197.36523  , 188.36523  , 149.36523  ],
#            ...,
#            [230.       , 246.       , 245.       ],
#            [230.       , 246.       , 245.       ],
#            [230.       , 246.       , 245.       ]],
#
#           [[191.40234  , 183.40234  , 147.40234  ],
#            [193.18625  , 183.49484  , 147.34055  ],
#            [193.44937  , 184.44937  , 145.44937  ],
#            ...,
#            [230.       , 246.       , 245.       ],
#            [230.       , 246.       , 245.       ],
#            [230.       , 246.       , 245.       ]]],
#
#
#          [[[254.       , 248.       , 152.       ],
#            [254.13281  , 248.13281  , 152.13281  ],
#            [254.55469  , 248.55469  , 152.55469  ],
#            ...,
#            [239.89062  , 196.55469  , 115.       ],
#            [240.73438  , 196.13281  , 115.       ],
#            [241.       , 196.       , 115.       ]],
#
#           [[253.89844  , 247.89844  , 151.89844  ],
#            [254.038    , 248.038    , 152.038    ],
#            [254.4813   , 248.4813   , 152.4813   ],
#            ...,
#            [239.96957  , 196.70703  , 115.25391  ],
#            [240.7919   , 196.28516  , 115.25391  ],
#            [241.05078  , 196.15234  , 115.25391  ]],
#
#           [[253.16406  , 247.16406  , 151.16406  ],
#            [253.35239  , 247.35239  , 151.35239  ],
#            [253.95059  , 247.95059  , 151.95059  ],
#            ...,
#            [240.54044  , 197.8086   , 117.08984  ],
#            [241.20786  , 197.38672  , 117.08984  ],
#            [241.41797  , 197.2539   , 117.08984  ]],
#
#           ...,
#
#           [[236.41797  , 199.41797  , 111.41797  ],
#            [236.39618  , 199.39618  , 111.26337  ],
#            [236.32697  , 199.32697  , 110.77228  ],
#            ...,
#            [254.       , 255.       , 179.       ],
#            [254.       , 255.       , 179.       ],
#            [254.       , 255.       , 179.       ]],
#
#           [[236.05078  , 199.05078  , 111.05078  ],
#            [235.93146  , 198.93146  , 110.798645 ],
#            [235.55243  , 198.55243  , 109.99774  ],
#            ...,
#            [254.       , 255.       , 179.       ],
#            [254.       , 255.       , 179.       ],
#            [254.       , 255.       , 179.       ]],
#
#           [[236.       , 199.       , 111.       ],
#            [235.86719  , 198.86719  , 110.734375 ],
#            [235.44531  , 198.44531  , 109.890625 ],
#            ...,
#            [254.       , 255.       , 179.       ],
#            [254.       , 255.       , 179.       ],
#            [254.       , 255.       , 179.       ]]],
#
#
#          [[[206.       , 219.       , 175.       ],
#            [206.       , 219.       , 175.       ],
#            [206.       , 219.       , 175.       ],
#            ...,
#            [215.       , 224.       , 181.       ],
#            [215.       , 224.       , 181.       ],
#            [215.       , 224.       , 181.       ]],
#            [212.09407  , 199.09407  , 209.09407  ],
#            [211.34492  , 198.34492  , 208.34492  ],
#            ...,
#            [212.31914  , 191.31914  , 206.31914  ],
#            [212.73405  , 191.73405  , 206.73405  ],
#            [213.       , 192.       , 207.       ]],
#
#           [[211.57227  , 198.57227  , 208.57227  ],
#            [211.03966  , 198.03966  , 208.03966  ],
#            [210.20866  , 197.20866  , 207.20866  ],
#            ...,
#            [212.06413  , 191.49187  , 205.20866  ],
#            [212.89513  , 192.32286  , 206.03966  ],
#            [213.42773  , 192.85547  , 206.57227  ]],
#
#           [[211.       , 198.       , 208.       ],
#            [210.2539   , 197.2539   , 207.2539   ],
#            [209.08984  , 196.08984  , 206.08984  ],
#            ...,
#            [212.08984  , 192.08984  , 204.08984  ],
#            [213.2539   , 193.2539   , 205.2539   ],
#            [214.       , 194.       , 206.       ]]]], dtype=float32)>,
#   <tf.Tensor: shape=(32,), dtype=int32, numpy=
#   array([ 1, 12, 10, 10,  1,  6,  1,  2,  6,  8, 10, 12, 10, 11,  2,  1,  1,
#           2, 11,  7,  8,  1,  1,  8,  1,  1,  6,  2, 12, 12, 13,  7],
#         dtype=int32)>)]

# %%
# приводим к численному виду
data_iterator = data_osetr.as_numpy_iterator()

# %%
# проходим по каждому batch
batch = data_iterator.next()

# %%
imgs, labels = next(data_iterator)
labels
# Out:
# array([ 1, 10,  1, 11, 11,  9,  1, 10, 11,  6,  1,  1,  6,  6, 10, 11,  1,
#        11,  8,  1, 10,  1,  1, 11,  1, 11, 10,  1,  1,  5,  0,  1],
#       dtype=int32)

# %%
# каждый класс (от 0 до 14) определяет клетку крови
# например 0 - базофил, 14 - эритробласт
fig, ax = plt.subplots(ncols=5, figsize=(20,20))
for idx, img in enumerate(batch[0][:5]):
    print(batch[1][idx])
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx] + 1)
# Out:
# 1
# 1
# 6
# 1
# 11

# %%
for image_batch, labels_batch in data_osetr:
  print(image_batch.shape)
  print(labels_batch.shape)
  break

#print(tf.data.experimental.cardinality(data_carp).numpy())
# Out:
# (32, 256, 256, 3)
# (32,)

# %% [markdown]
# Маштабируем данные

# %%
# значение batch[0] от 0 до 255
# приведет к значению от 0 до 1 для оптимизации
data = data_osetr.map(lambda x, y: (x / 255, y))

# %%
# опять приводим к виду numpy
data.as_numpy_iterator().next()[0][0]
# Out:
# 2023-06-30 15:05:40.530963: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [640]
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-30 15:05:40.531267: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [640]
# 	 [[{{node Placeholder/_4}}]]
# array([[[0.579079  , 0.44182405, 0.45751032],
#         [0.5757534 , 0.43987715, 0.45763144],
#         [0.5713848 , 0.44197303, 0.47023183],
#         ...,
#         [0.9764706 , 1.        , 1.        ],
#         [0.9764706 , 1.        , 1.        ],
#         [0.9764706 , 1.        , 1.        ]],
#
#        [[0.5764706 , 0.4392157 , 0.4549271 ],
#         [0.5751296 , 0.4392534 , 0.4573612 ],
#         [0.5699908 , 0.44057906, 0.47032782],
#         ...,
#         [0.9764706 , 1.        , 1.        ],
#         [0.9764706 , 1.        , 1.        ],
#         [0.9764706 , 1.        , 1.        ]],
#
#        [[0.5766447 , 0.44830525, 0.46707463],
#         [0.5792754 , 0.4507475 , 0.47251683],
#         [0.5796415 , 0.4502298 , 0.47997856],
#         ...,
#         [0.9764706 , 1.        , 1.        ],
#         [0.9764706 , 1.        , 1.        ],
#         [0.9764706 , 1.        , 1.        ]],
#
#        ...,
#
#        [[0.9598346 , 0.99905026, 1.        ],
#         [0.9596676 , 0.9988833 , 0.99983305],
#         [0.9588848 , 0.9981005 , 0.99905026],
#         ...,
#         [0.8277704 , 0.7293329 , 0.8018282 ],
#         [0.8413603 , 0.7452206 , 0.8168811 ],
#         [0.8253242 , 0.7291845 , 0.800845  ]],
#
#        [[0.95686275, 0.99607843, 1.        ],
#         [0.9561734 , 0.9953891 , 0.9993107 ],
#         [0.9529412 , 0.99215686, 0.99607843],
#         ...,
#         [0.8257368 , 0.7354151 , 0.7983487 ],
#         [0.84345186, 0.75936675, 0.8190564 ],
#         [0.81277573, 0.7299939 , 0.78903186]],
#
#        [[0.95686275, 0.99607843, 1.        ],
#         [0.9561734 , 0.9953891 , 0.9993107 ],
#         [0.9529412 , 0.99215686, 0.99607843],
#         ...,
#         [0.81656504, 0.72636896, 0.78911406],
#         [0.83491117, 0.7511795 , 0.8106924 ],
#         [0.8018034 , 0.7194505 , 0.778274  ]]], dtype=float32)

# %% [markdown]
# Разделение данных (train, validation, test)

# %%
len(data_osetr)
# Out:
# 20

# %%
len(data)
# Out:
# 20

# %%
train_size = round(len(data_osetr) * .8)
validation_size = round(len(data_osetr) * .1)
test_size = round(len(data_osetr)* .1)

# %%
train = data_osetr.take(train_size)
validation = data_osetr.skip(train_size).take(validation_size)
test = data_osetr.skip(train_size + validation_size).take(test_size)

'''
train = data.take(train_size)
validation = data.skip(train_size).take(validation_size)
test = data.skip(train_size + validation_size).take(test_size)
'''
# Out:
# '\ntrain = data.take(train_size)\nvalidation = data.skip(train_size).take(validation_size)\ntest = data.skip(train_size + validation_size).take(test_size)\n'

# %% [markdown]
# Создание нейронной модели

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, MaxPool2D, Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras import callbacks
import pandas as pd

# %%
'''
model = Sequential([
    Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)),
    MaxPooling2D(),
    Conv2D(32, (3,3), 1, activation='relu'),
    MaxPooling2D(),
    Conv2D(16, (3,3), 1, activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(256, activation='relu'),
    Dense(1, activation='sigmoid')
])
'''

'''
# accuracy_best = 0.06
model = Sequential([
    Conv2D(16, (3,3), 1, activation='relu', padding = 'same', input_shape=(256,256,3)),
    MaxPool2D(pool_size=(2,2)),
    Conv2D(32, (3,3), 1, activation='relu', padding = 'same'),
    MaxPool2D(pool_size=(2,2)),
    Conv2D(16, (3,3), 1, activation='relu', padding = 'same'),
    MaxPool2D(pool_size=(2,2)),
    Flatten(),
    Dense(256, activation='relu'),
    #Dropout(0.5),
    Dense(15, activation='softmax'),
    #Flatten() # Иначе ошибка при model.fit()
    #GlobalAveragePooling2D()

])
'''


# accuracy_best = 0.375
model = Sequential([
    Conv2D(filters = 16, 
           kernel_size = (3, 3), 
           strides = (1, 1), 
           padding = 'same', 
           activation='relu', 
           input_shape = (256, 256, 3)),
    MaxPool2D(pool_size=(2, 2)),
    Flatten(),
    Dense(256, activation='relu'),
    #Dropout(0.5),
    Dense(14, activation='softmax'),
    #Flatten() # Иначе ошибка при model.fit()
    #GlobalAveragePooling2D()

])

# %%
'''
model.compile(
    optimizer='adam',
    loss=tf.losses.BinaryCrossentropy(),
    metrics=['accuracy']
)
'''

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  flatten (Flatten)           (None, 262144)            0
#
#  dense (Dense)               (None, 256)               67109120
#
#  dense_1 (Dense)             (None, 14)                3598
#
# =================================================================
# Total params: 67,113,166
# Trainable params: 67,113,166
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Обучение

# %%
# тут можно добавить логи, но пока не разобрался как

# %%
# остановка при стагнации
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=3, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# %%
history = model.fit(x = train, epochs = 20, validation_data=validation, callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 2023-06-30 15:05:44.667417: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [640]
# 	 [[{{node Placeholder/_4}}]]
# 2023-06-30 15:05:44.667678: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [640]
# 	 [[{{node Placeholder/_4}}]]
# 16/16 [==============================] - ETA: 0s - loss: 10221.0957 - accuracy: 0.2578
# 2023-06-30 15:05:54.514790: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [640]
# 	 [[{{node Placeholder/_4}}]]
# 2023-06-30 15:05:54.515034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [640]
# 	 [[{{node Placeholder/_4}}]]
# 16/16 [==============================] - 10s 617ms/step - loss: 10221.0957 - accuracy: 0.2578 - val_loss: 3335.1030 - val_accuracy: 0.4844
# Epoch 2/20
# 16/16 [==============================] - 10s 621ms/step - loss: 1470.7863 - accuracy: 0.4414 - val_loss: 465.5311 - val_accuracy: 0.2812
# Epoch 3/20
# 16/16 [==============================] - 10s 616ms/step - loss: 253.6762 - accuracy: 0.4062 - val_loss: 114.5182 - val_accuracy: 0.4531
# Epoch 4/20
# 16/16 [==============================] - 10s 605ms/step - loss: 77.5424 - accuracy: 0.5371 - val_loss: 33.0401 - val_accuracy: 0.6250
# Epoch 5/20
# 16/16 [==============================] - 10s 613ms/step - loss: 37.0820 - accuracy: 0.5449 - val_loss: 42.7635 - val_accuracy: 0.5938
# Epoch 6/20
# 16/16 [==============================] - 10s 600ms/step - loss: 20.7974 - accuracy: 0.6055 - val_loss: 16.1521 - val_accuracy: 0.6094
# Epoch 7/20
# 16/16 [==============================] - 10s 605ms/step - loss: 19.0081 - accuracy: 0.6094 - val_loss: 6.9190 - val_accuracy: 0.7344
# Epoch 8/20
# 16/16 [==============================] - 10s 600ms/step - loss: 13.8327 - accuracy: 0.6758 - val_loss: 8.1711 - val_accuracy: 0.6094
# Epoch 9/20
# 16/16 [==============================] - 10s 607ms/step - loss: 8.0824 - accuracy: 0.6875 - val_loss: 5.6413 - val_accuracy: 0.6562
# Epoch 10/20
# 16/16 [==============================] - 10s 617ms/step - loss: 7.3166 - accuracy: 0.7090 - val_loss: 7.3141 - val_accuracy: 0.7344
# Epoch 11/20
# 16/16 [==============================] - 10s 604ms/step - loss: 6.3445 - accuracy: 0.7051 - val_loss: 5.7488 - val_accuracy: 0.7344
# Epoch 12/20
# 16/16 [==============================] - 10s 604ms/step - loss: 3.6407 - accuracy: 0.7402 - val_loss: 2.2482 - val_accuracy: 0.8125
# Epoch 13/20
# 16/16 [==============================] - 10s 605ms/step - loss: 3.5766 - accuracy: 0.7344 - val_loss: 2.5251 - val_accuracy: 0.7812
# Epoch 14/20
# 16/16 [==============================] - 10s 606ms/step - loss: 2.6685 - accuracy: 0.7871 - val_loss: 1.6516 - val_accuracy: 0.8438
# Epoch 15/20
# 16/16 [==============================] - 10s 598ms/step - loss: 3.3203 - accuracy: 0.7891 - val_loss: 6.7508 - val_accuracy: 0.7969
# Epoch 16/20
# 16/16 [==============================] - 10s 596ms/step - loss: 2.7746 - accuracy: 0.7969 - val_loss: 2.6624 - val_accuracy: 0.7500
# Epoch 17/20
# 16/16 [==============================] - 10s 600ms/step - loss: 2.6567 - accuracy: 0.7715 - val_loss: 1.3558 - val_accuracy: 0.7500
# Epoch 18/20
# 16/16 [==============================] - 10s 597ms/step - loss: 2.8553 - accuracy: 0.7832 - val_loss: 4.1215 - val_accuracy: 0.7969
# Epoch 19/20
# 16/16 [==============================] - 10s 598ms/step - loss: 2.3232 - accuracy: 0.8242 - val_loss: 0.8265 - val_accuracy: 0.8281
# Epoch 20/20
# 16/16 [==============================] - 10s 596ms/step - loss: 5.8737 - accuracy: 0.7480 - val_loss: 1.1668 - val_accuracy: 0.8594

# %%
validation
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# Plots

# %%
# вывод в виде граффика
xi = [0, 1, 2, 3, 4]
x = [1, 2, 3, 4, 5]
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(color = ['blue', 'dodgerblue'], 
                                             marker = 'o',
                                             grid = True,);
plt.ylabel('Loss value')
plt.xlabel('Epoch')
plt.xticks(xi, x)
print("Minimum validation loss: {}".format(history_df['val_loss'].min()))

history_df.loc[:, ['loss', 'val_loss']].plot(color = ['blue', 'dodgerblue'], 
                                             marker = 'o',
                                             grid = True,);
# Out:
# Minimum validation loss: 0.826502799987793

# %%
history_df.loc[:, ['loss', 'val_loss']]
# Out:
#             loss     val_loss
# 0   10221.095703  3335.103027
# 1    1470.786255   465.531128
# 2     253.676224   114.518188
# 3      77.542404    33.040066
# 4      37.081963    42.763542
# 5      20.797419    16.152115
# 6      19.008076     6.919011
# 7      13.832721     8.171064
# 8       8.082429     5.641341
# 9       7.316618     7.314073
# 10      6.344490     5.748825
# 11      3.640705     2.248192
# 12      3.576610     2.525139
# 13      2.668497     1.651601
# 14      3.320287     6.750838
# 15      2.774632     2.662359
# 16      2.656717     1.355848
# 17      2.855278     4.121482
# 18      2.323170     0.826503
# 19      5.873746     1.166834

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['accuracy', 'val_accuracy']].plot();
print("Maximum validation accuracy: {}".format(history_df['val_accuracy'].min()))

history_df.loc[:, ['accuracy', 'val_accuracy']].plot(color = ['blue', 'dodgerblue'], 
                                             marker = 'o',
                                             grid = True,);
# Out:
# Maximum validation accuracy: 0.28125

# %% [markdown]
# Оценка

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy, Accuracy

# %%
precision = Precision()
recall = Recall()
accuracy = Accuracy()

i = 0


float_formatter = "{:.4}".format

figure_nrows = 2
figure_ncols = 3
figure_nplots = figure_nrows * figure_ncols

fig, ax = plt.subplots(nrows = figure_nrows, ncols = figure_ncols, figsize = (15, 10))
for batch in test.as_numpy_iterator(): 
    print(i)
    i += 1
    X, y = batch
    yhat = model.predict(X)
    y_pred = np.asarray([np.argmax(i) for i in yhat], dtype = 'int32')
    y_pred_prob = (np.asarray([np.max(i) for i in yhat], dtype = 'float32') * 100)
    precision.update_state(y, y_pred)
    recall.update_state(y, y_pred)
    accuracy.update_state(y, y_pred)

    col_idx = 0
    row_idx = 0
    for idx, img in enumerate(batch[0][:figure_nplots]):

        if col_idx == figure_ncols:
            col_idx = 0
            row_idx += 1

        print(batch[1][idx])
        ax[row_idx, col_idx].imshow(img.astype(int))
        plot_text = f'Factual:     {y[idx] + 1} \nPredicted: {y_pred[idx] + 1} ({float_formatter(y_pred_prob[idx])} %)'
        #ax[row_idx, col_idx].title.set_text(plot_text)
        
        ax[row_idx, col_idx].set_title(plot_text, loc = 'left')

        col_idx += 1

print('y:')
print(y)
print('y_pred:')
print(y_pred)
print(f'Precision: {precision.result()}, Recall:{recall.result()}, Accuracy: {accuracy.result()}')
print()
# Out:
# 0
# 1/1 [==============================] - 0s 84ms/step
# 2
# 8
# 10
# 11
# 8
# 1
# 1
# 1/1 [==============================] - 0s 87ms/step
# 1
# 1
# 2
# 11
# 10
# 5
# y:
# [ 1  1  2 11 10  5  2  7 11 13 12  1  2  2  2  6  1  6 11 10  8  7  7  1
#   6 11 12  4 12  1 10  1]
# y_pred:
# [ 1  1  1 11  1  2 11 11 11  8 11  1  1  1  2  6  1 11 11 10  8  7  7  1
#   6 11  1  4  1  1  1  1]
# Precision: 1.0, Recall:1.0, Accuracy: 0.578125

# %%
# каждый класс (от 0 до 14) определяет клетку крови
# например 0 - базофил, 14 - эритробласт
fig, ax = plt.subplots(ncols=5, figsize=(20,20))
for idx, img in enumerate(batch[0][:5]):
    print(batch[1][idx])
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx] + 1)
# Out:
# 11
# 11
# 1
# 11
# 8

# %%
yhat
# Out:
# array([[0.00000000e+00, 1.70892263e-26, 3.89610420e-07, 5.41536876e-33,
#         1.35586421e-22, 2.10609530e-27, 6.21321306e-08, 5.62395696e-21,
#         3.21268678e-19, 3.35698180e-25, 1.94216341e-07, 9.99999225e-01,
#         5.03843432e-37, 0.00000000e+00],
#        [5.63746726e-04, 1.17704021e-02, 7.22466066e-05, 8.60079016e-14,
-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [2.30644102e-04, 9.89832450e-03, 2.11537525e-04, 2.92196443e-13,
#         6.90657886e-09, 1.68611892e-04, 4.87815179e-02, 4.39443767e-01,
#         1.04568284e-02, 2.49469606e-03, 4.77180629e-06, 4.88308787e-01,
#         4.16544822e-07, 2.72966606e-35],
#        [7.81791168e-05, 1.28091350e-02, 4.20724787e-03, 2.78419821e-09,
#         2.34445906e-05, 2.48270258e-01, 6.54958858e-05, 3.77433538e-01,
#         2.25152093e-04, 4.52803826e-04, 3.44272524e-01, 1.21620754e-02,
#         1.16177503e-07, 6.09896942e-33],
#        [0.00000000e+00, 1.99614890e-29, 6.23453774e-38, 0.00000000e+00,
#         2.77831024e-30, 8.54296331e-36, 9.92086863e-28, 9.99999940e-01,
#         1.53342435e-34, 2.76606681e-28, 1.08916484e-37, 1.15864065e-22,
#         0.00000000e+00, 0.00000000e+00]], dtype=float32)

# %%
y
# Out:
# array([11, 11,  1, 11,  8, 11,  1,  1,  2, 10, 10, 11,  1,  1, 11,  4,  1,
#        12,  1,  7,  1,  1, 11, 11,  5,  2, 12,  0,  1,  7, 10,  7],
#       dtype=int32)

# %%
y_pred
# Out:
# array([11, 11,  7, 11,  8, 11,  1,  1,  2, 10, 11, 11,  1,  1, 11,  8,  1,
#        11,  1,  7,  1, 11, 11, 11,  1,  2,  1,  1,  1, 11,  7,  7],
#       dtype=int32)

# %%
#y[13] == y_pred[13]

# %%
print(f'Precision: {precision.result()}, Recall:{recall.result()}, Accuracy: {accuracy.result()}')
# по итогу видно, что accuracy (точность) = 0.02, что очень мало.
# необходимо приближать это значение к 1.0
# Out:
# Precision: 0.984375, Recall:1.0, Accuracy: 0.625

# %%
accuracy.result().numpy()
# Out:
# 0.625

# %%
precision.update_state(y, y_pred)

# %%
train
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# '''
# https://www.kaggle.com/search?q=multi+classification+images+conv2d
# https://www.kaggle.com/code/kanncaa1/convolutional-neural-network-cnn-tutorial

# https://www.tensorflow.org/tutorials/images/classification

# '''


# # confusion matrix
# import seaborn as sns
# # Predict the values from the validation dataset
# Y_pred = model.predict(X_val)
# # Convert predictions classes to one hot vectors 
# Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# # Convert validation observations to one hot vectors
# Y_true = np.argmax(Y_val,axis = 1) 
# # compute the confusion matrix
# confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# # plot the confusion matrix
# f,ax = plt.subplots(figsize=(8, 8))
# sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray", fmt= '.1f',ax=ax)
# plt.xlabel("Predicted Label")
# plt.ylabel("True Label")
# plt.title("Confusion Matrix")
# plt.show()
# Out:
# 1/1 [==============================] - 0s 80ms/step
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[51], line 17
#      15 Y_pred_classes = np.argmax(Y_pred,axis = 1)
#      16 # Convert validation observations to one hot vectors
# ---> 17 Y_true = np.argmax(y, axis = 1)
#      18 # compute the confusion matrix
#      19 confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
#
# File <__array_function__ internals>:180, in argmax(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1216, in argmax(a, axis, out, keepdims)
#    1129 """
#    1130 Returns the indices of the maximum values along an axis.
#    1131
#    (...)
#    1213 (2, 1, 4)
#    1214 """
#    1215 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1216 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# AxisError: axis 1 is out of bounds for array of dimension 1
